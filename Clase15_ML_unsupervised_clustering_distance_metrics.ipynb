# %% [markdown]
# Buscar en Kaggle un dataset para aplicarle un modelo de regresión (cualquiera) y otro dataset para aplicarle un modelo de clasificación (cualquiera), con sus respectivas métricas de desempeño e histograma de errores. El dataset debe ser distinto a los ya vistos en clase.
